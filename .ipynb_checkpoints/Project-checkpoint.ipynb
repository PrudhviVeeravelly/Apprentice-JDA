# %%
from markovclick import dummy
clickstream = dummy.gen_random_clickstream(n_of_streams=100, n_of_pages=20)
clickstream
# Out:
# [['P19', 'P7', 'P18', 'P1', 'P3', 'P12', 'P11', 'P3', 'P16', 'P0', 'P14'],
#  ['P0', 'P4', 'P7', 'P4', 'P9', 'P0', 'P15', 'P11'],
#  ['P11', 'P6', 'P14', 'P0', 'P3', 'P16', 'P13', 'P12'],
#  ['P13', 'P1', 'P17', 'P6', 'P16', 'P12', 'P14', 'P11', 'P1', 'P9'],
#  ['P15', 'P6', 'P1', 'P4', 'P6', 'P14', 'P16', 'P18', 'P17', 'P15', 'P16'],
#  ['P7', 'P12', 'P8', 'P8', 'P3', 'P12', 'P7', 'P1'],
#  ['P7', 'P1', 'P9', 'P11', 'P5', 'P2', 'P5', 'P18', 'P16', 'P12'],
#  ['P16', 'P19', 'P4', 'P10', 'P5', 'P5', 'P0', 'P8', 'P19', 'P5'],
#  ['P15', 'P16', 'P17', 'P13', 'P1', 'P10', 'P14', 'P17', 'P10', 'P2', 'P17'],
#  ['P8', 'P7', 'P1', 'P18', 'P7', 'P5', 'P15', 'P14'],
#  ['P9', 'P3', 'P5', 'P1', 'P18', 'P4', 'P11', 'P4', 'P19', 'P2'],
#  ['P16', 'P15', 'P18', 'P1', 'P16', 'P17', 'P6', 'P5', 'P8', 'P19'],
#  ['P0', 'P5', 'P6', 'P12', 'P18', 'P8', 'P5', 'P5', 'P16', 'P19', 'P14'],
#  ['P6', 'P1', 'P15', 'P12', 'P14', 'P2', 'P1', 'P13'],
#  ['P17', 'P4', 'P12', 'P9', 'P14', 'P6', 'P14', 'P9', 'P4', 'P18'],
#  ['P1', 'P10', 'P15', 'P13', 'P6', 'P10', 'P15', 'P6', 'P15'],
#  ['P1', 'P1', 'P12', 'P14', 'P1', 'P16', 'P3', 'P13', 'P7', 'P7'],
#  ['P13', 'P18', 'P7', 'P8', 'P0', 'P5', 'P9', 'P3', 'P0'],
#  ['P15', 'P13', 'P11', 'P12', 'P9', 'P15', 'P12', 'P16'],
#  ['P13', 'P4', 'P10', 'P16', 'P19', 'P16', 'P5', 'P2', 'P15', 'P2', 'P4'],
#  ['P18', 'P2', 'P5', 'P11', 'P7', 'P11', 'P2', 'P10', 'P2', 'P18'],
#  ['P11', 'P18', 'P14', 'P16', 'P19', 'P7', 'P14', 'P11', 'P7', 'P8', 'P12'],
#  ['P19', 'P2', 'P7', 'P12', 'P10', 'P3', 'P6', 'P17', 'P15'],
#  ['P16', 'P0', 'P4', 'P5', 'P13', 'P18', 'P8', 'P19', 'P3', 'P15', 'P18'],
#  ['P0', 'P7', 'P1', 'P12', 'P15', 'P6', 'P3', 'P0', 'P2', 'P2'],
#  ['P15', 'P7', 'P2', 'P2', 'P3', 'P19', 'P11', 'P6', 'P2', 'P10', 'P2'],
#  ['P18', 'P4', 'P9', 'P11', 'P11', 'P17', 'P3', 'P18', 'P12', 'P6', 'P5'],
#  ['P15', 'P9', 'P19', 'P11', 'P9', 'P19', 'P16', 'P1'],
#  ['P13', 'P2', 'P17', 'P17', 'P13', 'P2', 'P18', 'P16', 'P0', 'P8', 'P15'],
#  ['P7', 'P0', 'P17', 'P13', 'P5', 'P11', 'P10', 'P18', 'P13', 'P13', 'P4'],
#  ['P14', 'P6', 'P14', 'P19', 'P10', 'P5', 'P2', 'P17'],
#  ['P4', 'P1', 'P14', 'P2', 'P17', 'P4', 'P7', 'P13', 'P7', 'P15'],
#  ['P13', 'P3', 'P18', 'P9', 'P2', 'P7', 'P7', 'P8', 'P16'],
#  ['P16', 'P18', 'P9', 'P14', 'P19', 'P3', 'P13', 'P11'],
#  ['P2', 'P5', 'P15', 'P13', 'P0', 'P7', 'P0', 'P2', 'P14'],
#  ['P9', 'P11', 'P16', 'P8', 'P9', 'P19', 'P11', 'P6', 'P13'],
#  ['P12', 'P11', 'P10', 'P9', 'P0', 'P16', 'P2', 'P11'],
#  ['P0', 'P11', 'P3', 'P6', 'P17', 'P8', 'P3', 'P2', 'P17', 'P14'],
#  ['P16', 'P19', 'P19', 'P5', 'P5', 'P3', 'P11', 'P11', 'P7'],
#  ['P14', 'P14', 'P8', 'P12', 'P0', 'P19', 'P6', 'P10', 'P3', 'P1'],
#  ['P15', 'P9', 'P18', 'P6', 'P11', 'P13', 'P7', 'P8', 'P2', 'P13'],
#  ['P11', 'P11', 'P19', 'P13', 'P10', 'P18', 'P18', 'P8', 'P11'],
#  ['P8', 'P11', 'P1', 'P6', 'P19', 'P1', 'P4', 'P18', 'P14'],
#  ['P14', 'P1', 'P17', 'P16', 'P9', 'P7', 'P10', 'P9', 'P1', 'P9', 'P14'],
#  ['P15', 'P6', 'P16', 'P13', 'P18', 'P4', 'P11', 'P9', 'P2'],
#  ['P19', 'P15', 'P15', 'P3', 'P11', 'P11', 'P6', 'P1'],
#  ['P2', 'P2', 'P17', 'P19', 'P2', 'P3', 'P11', 'P16', 'P16'],
#  ['P2', 'P1', 'P17', 'P13', 'P14', 'P5', 'P6', 'P4', 'P19'],
#  ['P19', 'P7', 'P12', 'P6', 'P15', 'P6', 'P3', 'P11', 'P10', 'P12', 'P10'],
#  ['P6', 'P18', 'P8', 'P3', 'P6', 'P17', 'P8', 'P11', 'P18', 'P15'],
#  ['P0', 'P5', 'P7', 'P8', 'P4', 'P15', 'P1', 'P15', 'P17', 'P2', 'P19'],
#  ['P17', 'P13', 'P9', 'P6', 'P1', 'P5', 'P18', 'P15'],
#  ['P16', 'P5', 'P2', 'P6', 'P3', 'P6', 'P9', 'P1', 'P10', 'P3'],
#  ['P17', 'P11', 'P14', 'P14', 'P6', 'P15', 'P4', 'P17', 'P9'],
#  ['P9', 'P7', 'P0', 'P5', 'P17', 'P18', 'P17', 'P12'],
#  ['P12', 'P5', 'P0', 'P0', 'P8', 'P18', 'P7', 'P3', 'P1', 'P11', 'P14'],
#  ['P12', 'P13', 'P7', 'P11', 'P10', 'P8', 'P10', 'P18', 'P11'],
#  ['P2', 'P17', 'P10', 'P13', 'P11', 'P18', 'P3', 'P3', 'P0'],
#  ['P0', 'P14', 'P5', 'P4', 'P0', 'P10', 'P11', 'P6'],
#  ['P19', 'P9', 'P17', 'P18', 'P11', 'P17', 'P15', 'P13'],
#  ['P6', 'P6', 'P8', 'P2', 'P14', 'P0', 'P10', 'P13', 'P12'],
#  ['P4', 'P5', 'P5', 'P1', 'P17', 'P5', 'P15', 'P15', 'P8', 'P10', 'P12'],
#  ['P8', 'P16', 'P12', 'P8', 'P19', 'P13', 'P17', 'P14'],
#  ['P2', 'P19', 'P7', 'P18', 'P10', 'P3', 'P10', 'P6', 'P0'],
#  ['P3', 'P6', 'P18', 'P8', 'P1', 'P12', 'P6', 'P9'],
#  ['P14', 'P12', 'P10', 'P18', 'P0', 'P15', 'P16', 'P12', 'P2', 'P17', 'P19'],
#  ['P14', 'P13', 'P5', 'P14', 'P19', 'P18', 'P0', 'P19', 'P14', 'P9'],
#  ['P16', 'P15', 'P8', 'P7', 'P5', 'P4', 'P6', 'P12', 'P15', 'P7', 'P0'],
#  ['P6', 'P16', 'P7', 'P15', 'P0', 'P1', 'P1', 'P1'],
#  ['P2', 'P7', 'P14', 'P1', 'P17', 'P12', 'P3', 'P8'],
#  ['P9', 'P19', 'P10', 'P13', 'P16', 'P6', 'P7', 'P14', 'P15', 'P6'],
#  ['P12', 'P10', 'P14', 'P0', 'P19', 'P9', 'P6', 'P14', 'P10'],
#  ['P14', 'P4', 'P5', 'P19', 'P11', 'P8', 'P0', 'P6', 'P6'],
#  ['P3', 'P5', 'P8', 'P0', 'P7', 'P18', 'P7', 'P9'],
#  ['P17', 'P8', 'P1', 'P1', 'P7', 'P14', 'P18', 'P16', 'P7', 'P12', 'P19'],
#  ['P19', 'P11', 'P16', 'P15', 'P10', 'P11', 'P4', 'P3'],
#  ['P9', 'P7', 'P2', 'P2', 'P19', 'P17', 'P11', 'P8', 'P17', 'P16'],
#  ['P8', 'P3', 'P2', 'P9', 'P19', 'P12', 'P14', 'P12', 'P8', 'P5', 'P6'],
#  ['P1', 'P16', 'P8', 'P7', 'P3', 'P10', 'P2', 'P0', 'P12', 'P8'],
#  ['P12', 'P12', 'P7', 'P9', 'P13', 'P17', 'P5', 'P4', 'P3'],
#  ['P4', 'P18', 'P2', 'P16', 'P14', 'P17', 'P13', 'P10', 'P11', 'P11', 'P5'],
#  ['P0', 'P11', 'P8', 'P7', 'P2', 'P15', 'P14', 'P5', 'P12', 'P15'],
#  ['P10', 'P6', 'P18', 'P11', 'P15', 'P8', 'P2', 'P1', 'P10', 'P11'],
#  ['P4', 'P9', 'P4', 'P16', 'P0', 'P0', 'P1', 'P6', 'P5'],
#  ['P4', 'P18', 'P11', 'P16', 'P10', 'P6', 'P10', 'P14', 'P17', 'P2'],
#  ['P14', 'P13', 'P9', 'P7', 'P6', 'P7', 'P19', 'P18', 'P16', 'P4'],
#  ['P4', 'P10', 'P16', 'P4', 'P6', 'P13', 'P19', 'P9'],
#  ['P3', 'P7', 'P5', 'P14', 'P8', 'P16', 'P10', 'P4', 'P10', 'P7'],
#  ['P3', 'P9', 'P12', 'P10', 'P16', 'P8', 'P13', 'P13', 'P3', 'P3'],
#  ['P6', 'P10', 'P3', 'P13', 'P7', 'P2', 'P19', 'P2', 'P4', 'P1', 'P13'],
#  ['P14', 'P19', 'P18', 'P5', 'P17', 'P18', 'P2', 'P12', 'P11', 'P0', 'P7'],
#  ['P3', 'P12', 'P6', 'P2', 'P0', 'P0', 'P5', 'P18', 'P15', 'P8', 'P15'],
#  ['P1', 'P13', 'P12', 'P0', 'P2', 'P7', 'P10', 'P1', 'P8'],
#  ['P9', 'P5', 'P17', 'P0', 'P12', 'P0', 'P8', 'P8', 'P10', 'P11', 'P13'],
#  ['P6', 'P5', 'P7', 'P17', 'P15', 'P11', 'P8', 'P19'],
#  ['P16', 'P19', 'P6', 'P8', 'P13', 'P11', 'P10', 'P10', 'P5', 'P15', 'P11'],
#  ['P15', 'P2', 'P5', 'P9', 'P1', 'P6', 'P14', 'P11'],
#  ['P13', 'P18', 'P3', 'P12', 'P6', 'P0', 'P4', 'P5', 'P19', 'P7', 'P15'],
#  ['P5', 'P0', 'P10', 'P14', 'P1', 'P6', 'P8', 'P1', 'P0', 'P4', 'P16'],
#  ['P12', 'P11', 'P3', 'P18', 'P15', 'P16', 'P15', 'P0', 'P1', 'P9']]

# %%
import numpy as np,pandas as pd
d=pd.read_csv("C:/Users/admin/Desktop/Apprentice-JDA/clickstreampath.csv")
df=pd.DataFrame(d)
dff=df.values.tolist()
dff
# Out:
# [['user 2',
#   'p12',
#   'p5',
#   'p1',
#   'p2',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 3',
#   'p2',
#   'p2',
#   'p21',
#   'p20',
#   'p13',
#   'p5',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 4',
#   'p21',
#   'p20',
#   'p18',
#   'p7',
#   'p1 ',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 5',
#   'p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 6',
#   'p1',
#   'p2',
#   'p4',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 7',
#   'p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2',
#   nan],
#  ['user 8',
#   'p3',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 9',
#   'p1',
#   'p2',
#   'p20',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 10',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 11',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 12',
#   'p2',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 13',
#   'p8',
#   'p3',
#   'p2',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 14',
#   'p2',
#   'p3',
#   'p2',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 15',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 16',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 17',
#   'p1',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 18',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 19',
#   'p1',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 20',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 21',
#   'p1',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 22',
#   'p1',
#   'p4',
#   'p5',
#   'p6',
#   'p2',
#   'p2',
#   'p22',
#   'p2',
#   'p6',
#   'p5',
#   'p4',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 23',
#   'p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['user 24',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 25',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 26',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 27',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 28',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 29',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 30',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 31',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 32',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 33',
#   'p3',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 34',
#   'p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 35',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 36',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 37',
#   'p2',
#   'p2',
#   'p21',
#   'p20',
#   'p17',
#   'p7',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 38',
#   'p2',
#   'p21',
#   'p20 ',
#   'p11 ',
#   'p3 ',
#   'p1',
#   'p20',
#   'p1 ',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 39',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 40',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 41',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 42',
#   'p1',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 43',
#   'p20',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 44',
#   'p20',
#   'p20',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 45',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 46',
#   'p1',
#   'p1',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 47',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 48',
#   'p1',
#   'p1',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 49',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 50',
#   'p1',
#   'p20',
#   'p3',
#   'p4',
#   'p3',
#   'p20',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 51',
#   'p2',
#   'p3',
#   'p20',
#   'p2 ',
#   'p1 ',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 52',
#   'p20',
#   'p3 ',
#   'p20 ',
#   'p1 ',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 53',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 54',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 55',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 56',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 57',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 58',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 59',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 60',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 61',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 62',
#   'p20',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 63',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 64',
#   'p20',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 65',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 66',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 67',
#   'p7',
#   'p3',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 68',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 69',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 70',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 71',
#   'p1',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 72',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 73',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 74',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 75',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 76',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 77',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 78',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 79',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 80',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 81',
#   'p1',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 82',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 83',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 84',
#   'p20',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 85',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 86',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 87',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 88',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 89',
#   'p2',
#   'p13',
#   'p21',
#   'p20',
#   'p13',
#   'p13',
#   'p3',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 90',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 91',
#   'p2',
#   'p20',
#   'p21',
#   'p20',
#   'p9',
#   'p3',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 92',
#   'p1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 93',
#   'P22',
#   'P7',
#   'P6',
#   'P5',
#   'P4',
#   'P20',
#   'P1',
#   'P1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 94',
#   'P1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 95',
#   'P1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 96',
#   'P20',
#   'P1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 97',
#   'P3',
#   'P20',
#   'P2',
#   'P2',
#   'P20',
#   'P1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 98',
#   'P1',
#   'P4',
#   'P8',
#   'P4 ',
#   'P9',
#   'P4 ',
#   'P1 ',
#   'P1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 99',
#   'P12',
#   'P5 ',
#   'P2 ',
#   'P17 ',
#   'P18 ',
#   'P7 ',
#   'P2 ',
#   'P20 ',
#   'P1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan],
#  ['user 100',
#   'P1',
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan]]

# %%
dff2=[]
for line in dff:
     sample2=[]
     for ind in line:
        ind = str(ind)
        if ('nan' in ind) or ('user' in ind):
            pass
        else:
            sample2.append(ind)
        dff2.append(sample2)

# %%
dff2
# Out:
# [['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p12', 'p5', 'p1', 'p2'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p13', 'p5', 'p1'],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p21', 'p20', 'p18', 'p7', 'p1 '],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p2',
#   'p21',
#   'p20',
#   'p4',
#   'p3',
#   'p2',
#   'p2',
#   'p3',
#   'p6',
#   'p6',
#   'p4',
#   'p6',
#   'p6',
#   'p6',
#   'p7',
#   'p9',
#   'p4',
#   'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p1', 'p2', 'p4', 'p1'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p4',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p1',
#   'p1',
#   'p1',
#   'p2',
#   'p2',
#   'p5',
#   'p22',
#   'p7',
#   'p2',
#   'p2',
#   'p22',
#   'p6',
#   'p4',
#   'p2',
#   'p2'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p3', 'p1'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1', 'p2', 'p20'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p2'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p8', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p2', 'p3', 'p2', 'p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p1', 'p4', 'p5', 'p6', 'p2', 'p2', 'p22', 'p2', 'p6', 'p5', 'p4', 'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p5',
#   'p5',
#   'p4',
#   'p1',
#   'p1',
#   'p1',
#   'p22',
#   'p1',
#   'p6',
#   'p4 ',
#   'p2 ',
#   'p1',
#   'p6',
#   'p1',
#   'p6',
#   'p1',
#   'p1',
#   'p2',
#   'p5',
#   'p5',
#   'p5',
#   'p4',
#   'p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p3',
#   'p16',
#   'p3',
#   'p13',
#   'p20',
#   'p13',
#   'p3',
#   'p11',
#   'p3',
#   'p10',
#   'p3',
#   'p9',
#   'p3',
#   'p8',
#   'p3',
#   'p1',
#   'p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p2', 'p21', 'p20', 'p17', 'p7', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p2', 'p21', 'p20 ', 'p11 ', 'p3 ', 'p1', 'p20', 'p1 ', 'p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p1', 'p1'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ['p20'],
#  ...]

# %%
from markovclick.models import MarkovClickstream
m = MarkovClickstream(dff2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(17,8))
sns.heatmap(m.prob_matrix, xticklabels=m.pages, yticklabels=m.pages)

# %%
from graphviz import Digraph 
from markovclick.viz import visualise_markov_chain
graph = visualise_markov_chain(m)
graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-0faaf363566b> in <module>
# ----> 1 from graphviz import Digraph
#       2 from markovclick.viz import visualise_markov_chain
#       3 graph = visualise_markov_chain(m)
#       4 graph
#
# ModuleNotFoundError: No module named 'graphviz'
